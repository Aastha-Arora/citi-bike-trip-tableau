# %%
# Import Dependencies
import pandas as pd

# %%
jan_2019 = pd.read_csv("201901-citibike-tripdata.csv")

# %%
jan_2020 = pd.read_csv("202001-citibike-tripdata.csv")

# %%
# Combining both the dataframes
jan_19_20 = pd.concat([jan_2019, jan_2020], ignore_index=True)

# %%
jan_19_20
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...               ...                       ...                       ...
# 2207878          1587  2020-01-31 23:59:26.8820  2020-02-01 00:25:54.4890
# 2207879           222  2020-01-31 23:59:32.6410  2020-02-01 00:03:15.4720
# 2207880           163  2020-01-31 23:59:39.1780  2020-02-01 00:02:23.0400
# 2207881           327  2020-01-31 23:59:49.2310  2020-02-01 00:05:16.3790
# 2207882           484  2020-01-31 23:59:57.0360  2020-02-01 00:08:01.1820
#
#          start station id           start station name  \
# ...

# %%
# Replacing the number for gender: Gender (Zero=unknown; 1=male; 2=female)
jan_19_20['gender'] = jan_19_20['gender'].replace([0,1,2],['Unknown','Male','Female'])

# %%
jan_19_20 = jan_19_20.dropna(how='any')

# %%
jan_19_20["start station id"] = jan_19_20["start station id"].astype(int)

# %%
jan_19_20["end station id"] = jan_19_20["end station id"].astype(int)

# %%
jan_19_20
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...               ...                       ...                       ...
# 2207878          1587  2020-01-31 23:59:26.8820  2020-02-01 00:25:54.4890
# 2207879           222  2020-01-31 23:59:32.6410  2020-02-01 00:03:15.4720
# 2207880           163  2020-01-31 23:59:39.1780  2020-02-01 00:02:23.0400
# 2207881           327  2020-01-31 23:59:49.2310  2020-02-01 00:05:16.3790
# 2207882           484  2020-01-31 23:59:57.0360  2020-02-01 00:08:01.1820
#
#          start station id           start station name  \
# ...

# %%
jan_19_20.to_csv("citibike_jan_19_20.csv", index=False)
